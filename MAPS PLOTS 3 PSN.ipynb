# %%
import pandas as pd


data_file='/home/gfajardo/Desktop/Datos 121001/PSNfdiciembre2016.csv'
column_names=['Lat','Long','Alt','Dia','Seg']
Mli = pd.read_csv(data_file)#names=column_names)#, header=True)
Mli = Mli.drop(Mli.columns[[0]], axis=1)


Doy=355
Mli_filter = Mli[Mli['Dia'] == Doy]
Mli_filter =Mli_filter.sort_values(by=['Seg'], ascending=True)#Ordenar en función al tiempo en segundos#print(Mlif)


A = Mli_filter
print(A)
# Out:
#               Lat       Long       Alt  Dia    Seg
# 350965 -12.042418 -75.321394  3324.044  355      0
# 350966 -12.042418 -75.321394  3324.097  355      1
# 350967 -12.042418 -75.321394  3324.050  355      2
# 350968 -12.042418 -75.321394  3324.083  355      3
# 350969 -12.042418 -75.321394  3324.038  355      4
# 350970 -12.042418 -75.321394  3324.052  355      5
# 350971 -12.042417 -75.321393  3323.957  355      6
# 350972 -12.042417 -75.321393  3323.983  355      7
# 350973 -12.042417 -75.321393  3323.950  355      8
# 350974 -12.042417 -75.321393  3323.990  355      9
# 350975 -12.042417 -75.321393  3323.935  355     10
# 350976 -12.042417 -75.321393  3323.908  355     11
# 350977 -12.042417 -75.321393  3323.925  355     12
# 350978 -12.042417 -75.321393  3323.917  355     13
# 350979 -12.042417 -75.321393  3323.891  355     14
# 350980 -12.042417 -75.321393  3323.941  355     15
# 350981 -12.042417 -75.321393  3323.946  355     16
# ...

# %%
cd
# Out:
# /home/gfajardo

# %%
import pandas as pd



data_file='/home/gfajardo/Desktop/Datos 121001/Result-pos.csv'

column_names=['A','Año','B','C','Day','Tiempo']
    
Mli1= pd.read_csv(data_file)#,delim_whitespace=True,names=column_names)
A = Mli1.drop(Mli1.columns[[0]], axis=1)

pd.set_option('float_format', '{:f}'.format)

print(A)
# Out:
#               A          B           C  Dia    Seg
# 0    -12.042417 -75.321412 3321.017000   30  86269
# 1    -12.042417 -75.321412 3320.980000   30  86270
# 2    -12.042417 -75.321412 3320.957000   30  86271
# 3    -12.042417 -75.321412 3320.896000   30  86272
# 4    -12.042417 -75.321413 3320.875000   30  86273
# 5    -12.042417 -75.321412 3320.917000   30  86274
# 6    -12.042417 -75.321412 3320.919000   30  86275
# 7    -12.042417 -75.321412 3320.911000   30  86276
# 8    -12.042417 -75.321412 3320.944000   30  86277
# 9    -12.042417 -75.321412 3320.979000   30  86278
# 10   -12.042417 -75.321412 3320.968000   30  86279
# 11   -12.042417 -75.321412 3320.982000   30  86280
# 12   -12.042417 -75.321412 3320.981000   30  86281
# 13   -12.042417 -75.321412 3321.031000   30  86282
# 14   -12.042417 -75.321413 3320.759000   30  86283
# 15   -12.042417 -75.321412 3320.791000   30  86284
# 16   -12.042417 -75.321413 3320.787000   30  86285
# ...

# %%
# Deleting columns
# Delete the "A" column from the dataframe
#data = A.drop("D", axis=1)
data=A
#data1=data[data["Dia"] == 30]
df=data
#df=data1[data1["Day"] == 42 ]
df=df[['Lat','Long','Seg']]#.iloc[0:80]
df.describe()
#print(df)
# Out:
#                 Lat          Long           Seg
# count  86400.000000  86400.000000  86400.000000
# mean     -12.042413    -75.321411  43199.509444
# std        0.000006      0.000006  24941.676459
# min      -12.042429    -75.321430      0.000000
# 25%      -12.042417    -75.321416  21599.750000
# 50%      -12.042413    -75.321412  43199.500000
# 75%      -12.042409    -75.321407  64799.250000
# max      -12.042397    -75.321384  86399.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

BBox = (df.A.min(),   df.A.max(),      
         df.B.min(), df.B.max())
print(BBox)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-7c15cd1ff5b9> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 BBox = (df.A.min(),   df.A.max(),
#       6          df.B.min(), df.B.max())
#       7 print(BBox)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'A'

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(
    {'City': ['Huancayo', 'Brasilia'],
     'Country': ['Peru', 'Brazil',],
     'Latitude': [-12.043489, -15.78],
     'Longitude': [-75.322030, -47.91]})

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
print(type(world))
# We restrict to South America.
ax = world[world.continent == 'South America'].plot(color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
# sphinx_gallery_thumbnail_number = 3
import geopandas
df = world.to_crs(epsg=3857)
import contextily as ctx
# Out:
# /home/gfajardo/anaconda3/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-13fcbd2c4f7a> in <module>
#       2 import geopandas
#       3 df = world.to_crs(epsg=3857)
# ----> 4 import contextily as ctx
#
# ModuleNotFoundError: No module named 'contextily'

# %%
geopandas.datasets.available
#https://ec.europa.eu/eurostat/portal/page/portal/gisco_Geographical_information_maps/popups/references/administrative_units_statistical_units_1
#https://www.geogpsperu.com/2014/03/base-de-datos-peru-shapefile-shp-minam.html
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
print(type(world))
# We restrict to South America.
ax = world[world.continent == 'South America'].plot(color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()

# %%
import gmaps
 
gmaps.configure(api_key='AIzaSyB4xS_LSCRoCDoAKH7MVQkpcuW4_BvP3pc')
 
marker_locations = [
(-34.0, -59.166672),
(-32.23333, -64.433327),
(40.166672, 44.133331),
(51.216671, 5.0833302),
(51.333328, 4.25)
]
 
 
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='Add Your Key here')

# Geocoding an address
geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

# Look up an address with reverse geocoding
reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

# Request directions via public transit
now = datetime.now()
directions_result = gmaps.directions("Sydney Town Hall",
                                     "Parramatta, NSW",
                                     mode="transit",
                                     departure_time=now)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-407a39a5c7ff> in <module>
#       2 from datetime import datetime
#       3
# ----> 4 gmaps = googlemaps.Client(key='Add Your Key here')
#       5
#       6 # Geocoding an address
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps/client.py in __init__(self, key, client_id, client_secret, timeout, connect_timeout, read_timeout, retry_timeout, requests_kwargs, queries_per_second, channel, retry_over_query_limit)
#     117
#     118         if key and not key.startswith("AIza"):
# --> 119             raise ValueError("Invalid API key provided.")
#     120
#     121         if channel:
#
# ValueError: Invalid API key provided.

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key='AIzaSyB4xS_LSCRoCDoAKH7MVQkpcuW4_BvP3pc')
earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')
earthquake_df.head()
# Out:
#     latitude   longitude  magnitude
# 0  65.193300 -149.072500       1.70
# 1  38.791832 -122.780830       2.10
# 2  38.818001 -122.792168       0.48
# 3  33.601667 -116.727667       0.78
# 4  37.378334 -118.520836       3.64

# %%
locations = earthquake_df[['latitude', 'longitude']]
weights = earthquake_df['magnitude']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
import gmaps.datasets
 
gmaps.configure(api_key='AIzaSyB4xS_LSCRoCDoAKH7MVQkpcuW4_BvP3pc') 
fig = gmaps.figure(map_type='SATELLITE')
# generate some (latitude, longitude) pairs
locations = [(51.5, 0.1), (51.7, 0.2), (51.4, -0.2), (51.49, 0.1)]
heatmap_layer = gmaps.heatmap_layer(locations)
fig.add_layer(heatmap_layer)
fig

# %%
df.describe()
# Out:
#                 Lat          Long           Seg
# count  86400.000000  86400.000000  86400.000000
# mean     -12.042413    -75.321411  43199.509444
# std        0.000006      0.000006  24941.676459
# min      -12.042429    -75.321430      0.000000
# 25%      -12.042417    -75.321416  21599.750000
# 50%      -12.042413    -75.321412  43199.500000
# 75%      -12.042409    -75.321407  64799.250000
# max      -12.042397    -75.321384  86399.000000

# %%
import gmaps
 
gmaps.configure(api_key='AIzaSyDJBFgimcWgJxZKt1vB1nAu90Nblhh37gQ')
 
#marker_locations = [
#(-34.0, -59.166672),
#(-32.23333, -64.433327),
#(40.166672, 44.133331),
#(51.216671, 5.0833302),
#(51.333328, 4.25)
#]
 
marker_locations = df[['A','B']]
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
gmaps.configure(api_key='AIzaSyDJBFgimcWgJxZKt1vB1nAu90Nblhh37gQ')
nuclear_power_plants = [
{'name': 'Atucha', 'location': (-34.0, -59.167), 'active_reactors': 1},
{'name': 'Embalse', 'location': (-32.2333, -64.4333), 'active_reactors': 1},
{'name': 'Armenia', 'location': (40.167, 44.133), 'active_reactors': 1},
{'name': 'Br', 'location': (51.217, 5.083), 'active_reactors': 1},
{'name': 'Doel', 'location': (51.333, 4.25), 'active_reactors': 4},
{'name': 'Tihange', 'location': (50.517, 5.283), 'active_reactors': 3}
]
print(nuclear_power_plants)
plant_locations = [plant['location'] for plant in nuclear_power_plants]
info_box_template = """
<dl>
<dt>Name</dt><dd>{name}</dd>
<dt>Number reactors</dt><dd>{active_reactors}</dd>
</dl>
"""
plant_info = [info_box_template.format(**plant) for plant in nuclear_power_plants]
marker_layer = gmaps.marker_layer(plant_locations, info_box_content=plant_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# Out:
# [{'name': 'Atucha', 'location': (-34.0, -59.167), 'active_reactors': 1}, {'name': 'Embalse', 'location': (-32.2333, -64.4333), 'active_reactors': 1}, {'name': 'Armenia', 'location': (40.167, 44.133), 'active_reactors': 1}, {'name': 'Br', 'location': (51.217, 5.083), 'active_reactors': 1}, {'name': 'Doel', 'location': (51.333, 4.25), 'active_reactors': 4}, {'name': 'Tihange', 'location': (50.517, 5.283), 'active_reactors': 3}]
# Figure(layout=FigureLayout(height='420px'))

# %%
#import numpy as np
#import pandas as pd
#import matplotlib.pyplot as plt
#ruh_m = plt.imread('Screenshot_20200109_121540-2.png')
#fig, ax = plt.subplots(figsize = (16,14))
#fig, ax = plt.subplots(figsize = (10,8))
#ax.scatter(df['B'],df['A'], zorder=1, alpha= 0.2, c='b', s=10)
#ax.set_title('Observatorio de Huancayo')
#BBox = (-75.335329,-75.304503,-12.052810,-12.034576)
#ax.set_xlim(BBox[0],BBox[1])
#ax.set_ylim(BBox[2],BBox[3])
#ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
ruh_m = plt.imread('/home/gfajardo/Desktop/Bibliografía/Mes6/Screenshot_20200109_121540-2.png')
#fig, ax = plt.subplots(figsize = (16,14))
fig, ax = plt.subplots(figsize = (10,8))
ax.scatter(df['Lat'],df['Long'],zorder=5, alpha= 0.4, c='b', s=12)
ax.set_title('Observatorio de Huancayo')
BBox = (-75.335329,-75.304503,-12.052810,-12.034576)
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
df.to_csv(r'/home/gfajardo/Desktop/Summer-08&09-DOY-35-Huancayo-POS.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
ruh_m = plt.imread('/home/gfajardo/Desktop/Bibliografía/Mes6/Mapa Huancayo GPS.png')
#fig, ax = plt.subplots(figsize = (16,14))
fig, ax = plt.subplots(figsize = (20,16))
ax.scatter(df['Long'],df['Lat'],zorder=5, alpha= 0.4, c='b', s=12)



ax.set_title('Observatorio de Huancayo')#gfajardo/Desktop/Bibliografía/Mes6/Observatorio de Huancayo')
BBox = (-75.321424,-75.321400,-12.042429,-12.042406)
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
ruh_m = plt.imread('/home/gfajardo/Desktop/Bibliografía/Mes6/Mapa Huancayo GPS.png')
#fig, ax = plt.subplots(figsize = (16,14))
fig, ax = plt.subplots(figsize = (20,16))
im=ax.scatter(df['Long'],df['Lat'],zorder=5, alpha= 0.4, c=df['Seg']/3600, s=12)



ax.set_title('Observatorio de Huancayo DOY 355')#gfajardo/Desktop/Bibliografía/Mes6/Observatorio de Huancayo
#BBox = (-75.321414,-75.321410,-12.042419,-12.042416)
BBox = (-75.321434,-75.321390,-12.042432,-12.042394)
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])

ax.set_xlabel('Long')
ax.set_ylabel('Lat')

cb=fig.colorbar(im, ax=ax)
cb.set_label('Time')

plt.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
